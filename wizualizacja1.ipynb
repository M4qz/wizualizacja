# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

import geopandas
import zipfile, re, os

import warnings
df = pd.read_csv("https://raw.githubusercontent.com/marianwitkowski/python-data/master/data/otodom-head-sample.csv", sep=';', na_values=['None'])
df
# Out:
#      Unnamed: 0.1  Unnamed: 0     Lp     ID  \
# 0               1           1      2  41amC
# 1             128         128    131  44roG
# 2             199         199    204  3PyWy
# 3             205         205    210  44pe1
# 4             214         214    219  44mcg
# ..            ...         ...    ...    ...
# 295         16932       16938  17894  3lhlV
# 296         16997       17003  17963  3b6mM
# 297         17001       17007  17967  3aK8i
# 298         17032       17038  17998  2Y25z
# 299         17071       17079  23967  44rvK
#
#                                                    url  \
# 0    https://www.otodom.pl/oferta/port-67-ID41amC.h...
# 1    https://www.otodom.pl/oferta/kompaktowe-mieszk...
# 2    https://www.otodom.pl/oferta/apartament-z-5-sy...
# 3    https://www.otodom.pl/oferta/prestizowy-aparta...
# 4    https://www.otodom.pl/oferta/mieszkanie-w-spok...
# ..                                                 ...
# 295  https://www.otodom.pl/oferta/wolanowa-inwestyc...
# 296  https://www.otodom.pl/oferta/mieszkanie-swiezo...
# 297  https://www.otodom.pl/oferta/przestronne-miesz...
# 298  https://www.otodom.pl/oferta/plac-zbawiciela-o...
# 299  https://www.otodom.pl/oferta/mieszkanie-w-kami...
#
#                                                  title  rooms      price  \
# 0                                              Port 67      3        NaN
# 1    Kompaktowe mieszkanie - wiele możliwości aranż...      2   375000.0
# 2    Apartament z 5 sypialniami i oranżerią na Powiślu      8  3990000.0
# 3       Prestiżowy apartament na warszawskim Mokotowie      2  1149000.0
# 4      Mieszkanie w spokojnej okolicy z ogrodem 230 m2      3   695000.0
# ..                                                 ...    ...        ...
# 295     ***WOLA***Nowa Inwestycja***SUPER CENY***METRO      2   480000.0
# 296  Mieszkanie świeżo po remoncie, w zielonej okol...      3   515000.0
# 297      Przestronne mieszkanie czteropokojowe na Woli      4  1300000.0
# 298        Plac Zbawiciela / Okolica / winda / wysokie      4   850000.0
# 299  Mieszkanie W Kamienicy, Stara Ochota, Winda, 0...      3   850000.0
#
#      price_m2    area                   loc
# 0         NaN   66.93          Praga-Północ
# 1      7813.0   48.00                 Ursus
# 2     18783.0  212.43  Śródmieście, Powiśle
# 3     17677.0   65.00               Mokotów
# 4      6619.0  105.00             Białołęka
# ..        ...     ...                   ...
# 295   10909.0   44.00                  Wola
# 296    9035.0   57.00               Mokotów
# 297   10156.0  128.00                  Wola
# 298   10353.0   82.10           Śródmieście
# 299   12006.0   70.80  Ochota, Stara Ochota
#
# [300 rows x 11 columns]
